# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import os

# %%
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
# ...

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'account.txt',
#  'Amos_nami.txt',
#  'april_data_trials.ipynb',
#  'atm_mock.ipynb',
#  'BigBookSmallPythonProjects.pdf',
#  'chatbox_with_tim.ipynb',
#  'cousera_python_specialization1',
#  'data_professor_projects',
#  'decagon_circle.ipynb',
#  'do_you_know_him_her.ipynb',
#  'file_analyst.ipynb',
#  'friends_pref.txt',
#  'Justina_account.txt',
#  'Justina_nami.txt',
#  'login.py',
#  'login_program.ipynb',
#  'mini_data_science_project_with_mosh.ipynb',
#  'miscellaneous_june.ipynb',
#  'music-recommender.dot',
#  'music_data.csv',
#  'music_recommendation.joblib',
#  'music_recommender_model.svg',
#  'Omofaiye_account.txt',
#  'python_for_everybody_course.ipynb',
#  'student_score.txt']

# %%
for i in os.listdir():
    print('file', os.listdir().index(i) +1,'is', i)
    textfiles = []
    if '.txt' in i:
        textfiles.append(i)
        print(i)
    for i in textfiles:
        with open(i,'rt') as file:
            one = file.read()
            print('The contents of', i, 'is:\n', one)
# Out:
# file 1 is .ipynb_checkpoints
# file 2 is account.txt
# account.txt
# The contents of account.txt is:
#  0
# file 3 is Amos_nami.txt
# Amos_nami.txt
# The contents of Amos_nami.txt is:
#  Amos
# Omofaiye
# shema.omofaye@gmail.com
# Zerozia
# zero11
#
# file 4 is april_data_trials.ipynb
# file 5 is atm_mock.ipynb
# file 6 is BigBookSmallPythonProjects.pdf
# file 7 is chatbox_with_tim.ipynb
# file 8 is cousera_python_specialization1
# file 9 is data_professor_projects
# file 10 is decagon_circle.ipynb
# file 11 is do_you_know_him_her.ipynb
# file 12 is file_analyst.ipynb
# file 13 is friends_pref.txt
# friends_pref.txt
# The contents of friends_pref.txt is:
#  colorf:green
# foodf:rice
# drinkf:malt
# hobbyf:singing
# subjectf:english
# artistf:orlando
# town:ponyan
# mid_name:moses
# club:manchester united
# phone:techno
# file 14 is Justina_account.txt
# Justina_account.txt
# The contents of Justina_account.txt is:
#  45000
# 45000
# 45000
#
# file 15 is Justina_nami.txt
# ...
